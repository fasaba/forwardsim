# %%
## Forward simulator of haplotype frequencies with recombination

# %%
import numpy as np

# %%
# create generation 0 object
# set of original haplotypes which are sequences

# %%
# simulate a generation and create a generation object with contains haplotype objects
N0 = 100
Nprev = 100
Ncurrent = 100

# %%
# a haplotype object looks like this
myparents = np.array([1, 3])
myproportions = np.array([0.6, 0.4])
H1_1 = [myparents, myproportions]
H1_1
# Out:
# [array([1, 3]), array([0.6, 0.4])]

# %%
# to create each haplotype in any given generation 3 functions are required: get_recombinations, get_parents, get_proportions

# %%
# returns a 1D array containing 1 integer, the number of recombination events for new haplotype
def get_recombinations (r, L):
    "Returns number of recombination events drawn from poisson distribution given a scaled recombination rate"    
    lam =r*L  # scale recombination rate by length of haplotype
    recombinations = np.random.poisson(lam) # draw random value from poisson distribution being lambda the rescaled recombination rate 
    return recombinations

# %%
get_recombinations(2e-8, 10e6)
# Out:
# 1

# %%
# returns a 1D array containing the index of the parents of the haplotype drawn from the previous generation
def get_parents (recombinations, Nprev):
    "Returns a 1D array containing the index of the parents of the current haplotype drawn from the previous generation"
    numberOfparents = ((recombinations) + 1)
    parentsIndexes = np.array(range(1, (Nprev+1)))
    
    # random sampling of parents indexes from uniform distribution with replacement
    myParents = np.random.choice(parentsIndexes, numberOfparents, replace = True, p = [1/parentsIndexes.size]*parentsIndexes.size)
    return myParents

# %%
get_parents(1, 100)
# Out:
# array([16, 92])

# %%
# computes a 1D array of breakpoints, as many floats as recombination events drawn from a uniform normalised distribution
# returns a 1D array with proportions of each parent haplotype for descendant by computing differences between 0, successive breakpoints and 1  
def get_proportions (recombinations):
    "Picks randomly as many breakpoints as crossovers and returns 1D array with intervals between 0, the breakpoints and 1, i.e. the proportions parent haplotypes"
    breakpoints = np.random.uniform(0, 1, recombinations) # draw as many values from a uniform distribution as number of recombinations
    l = np.array([0, 1]) # create fixed limits for interval of proportions
    intervals = np.diff(np.sort(np.append(l, breakpoints), axis = None)) # calculate differences between sorted interval limits and breakpoints
    return intervals

# %%
get_proportions(2)
# Out:
# array([0.50385711, 0.46398656, 0.03215632])

# %%
# define class haplotype with attributes recombination rate and length in bp
class Haplotype:
    def __init__(self, scaledRecombinationRate=-1, popsizePrevGeneration=0):
        """Initialize a haplotype object.
        """
        self.myParentsFromPrevGeneration  = []
        self.myRecombinationIntervals = []
        self.numRecombinations = -1
        if (scaledRecombinationRate > 0 and popsizePrevGeneration > 0):
            self.haplotype_birth(scaledRecombinationRate, popsizePrevGeneration)
        else: 
            print("Uninitialized haplotype created! Still a foetus!! Who am I, why am I here?")
            
    def haplotype_birth(self, scaledRecombinationRate, popsizePrevGeneration):
        """Populate all internal haploytpe variables.
        """
        if (self.numRecombinations != -1):
            print("Already alive! Get out of my room!")
            return(None)
        self.numRecombinations = np.random.poisson(scaledRecombinationRate)
        self.get_parents(popsizePrevGeneration)
        self.get_proportions()
        
    # returns a 1D array containing the index of the parents of the haplotype drawn from the previous generation
    def get_parents (self, popsizePrevGeneration):
        """Returns a 1D array containing the index of the parents 
        of the current haplotype drawn from the previous generation
        """
        numberOfParents = ((self.numRecombinations) + 1)
        # random sampling of parents indexes from uniform distribution with replacement
        self.myParentsFromPrevGeneration = np.random.randint(popsizePrevGeneration, size=numberOfParents)
       
    # returns a 1D array with proportions of each parent haplotype for descendant by computing differences between 0, successive breakpoints and 1  
    def get_proportions (self):
        """Picks randomly as many breakpoints as crossovers and 
        returns 1D array with intervals between 0, the breakpoints 
        and 1, i.e. the proportions parent haplotypes"""
        breakpoints = np.random.uniform(0, 1, self.numRecombinations) # draw as many values from a uniform distribution as number of recombinations
        l = np.array([0, 1]) # create fixed limits for interval of proportions
        self.myRecombinationIntervals = np.diff(np.sort(np.append(l, breakpoints), axis = None)) # calculate differences between sorted interval limits and breakpoints
        
    def print_haplotype(self):
        """Print details of this haplotype.
        """
#        print("Number of recombinations: %d"%(self.numRecombinations))
        print("                 Parents: %s"%(", ".join([str(x) for x in self.myParentsFromPrevGeneration])))
        print("             Proportions: %s"%(", ".join([str(np.round(x, 3)) for x in self.myRecombinationIntervals])))

# %%
for i in range(200):
    testHaplotype = Haplotype()
#    testHaplotype.haplotype_birth(1,100)
    print("Replicate: %d"%(i))
    testHaplotype.print_haplotype()
# Out:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 0
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 1
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 2
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 3
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 4
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 5
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 6
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 7
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 8
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 9
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 10
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 11
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 12
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 13
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 14
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 15
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 16
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 17
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 18
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 19
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 20
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 21
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 22
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 23
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 24
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 25
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 26
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 27
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 28
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 29
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 30
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 31
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 32
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 33
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 34
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 35
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 36
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 37
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 38
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 39
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 40
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 41
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 42
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 43
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 44
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 45
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 46
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 47
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 48
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 49
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 50
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 51
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 52
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 53
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 54
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 55
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 56
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 57
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 58
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 59
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 60
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 61
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 62
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 63
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 64
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 65
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 66
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 67
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 68
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 69
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 70
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 71
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 72
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 73
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 74
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 75
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 76
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 77
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 78
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 79
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 80
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 81
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 82
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 83
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 84
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 85
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 86
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 87
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 88
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 89
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 90
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 91
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 92
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 93
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 94
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 95
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 96
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 97
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 98
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 99
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 100
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 101
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 102
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 103
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 104
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 105
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 106
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 107
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 108
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 109
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 110
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 111
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 112
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 113
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 114
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 115
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 116
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 117
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 118
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 119
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 120
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 121
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 122
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 123
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 124
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 125
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 126
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 127
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 128
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 129
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 130
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 131
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 132
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 133
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 134
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 135
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 136
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 137
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 138
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 139
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 140
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 141
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 142
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 143
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 144
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 145
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 146
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 147
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 148
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 149
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 150
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 151
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 152
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 153
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 154
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 155
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 156
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 157
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 158
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 159
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 160
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 161
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 162
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 163
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 164
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 165
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 166
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 167
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 168
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 169
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 170
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 171
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 172
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 173
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 174
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 175
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 176
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 177
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 178
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 179
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 180
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 181
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 182
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 183
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 184
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 185
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 186
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 187
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 188
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 189
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 190
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 191
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 192
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 193
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 194
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 195
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 196
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 197
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 198
# Number of recombinations: -1
#                  Parents:
#              Proportions:
# Uninitialized haplotype created! Still a foetus!!
# Replicate: 199
# Number of recombinations: -1
#                  Parents:
#              Proportions:

# %%
# define class generation with attribute 'populate' which is a for loop of instantiation of class haplotype as many times as Ncurrent
class Generation:
    def __init__(self, scaledRecombinationRate=-1, popsizePrevGeneration=0, popsizeCurGeneration=0):
        """Initialize a generation object.
        """
        self.haplotypes = []
        if (popsizeCurGeneration == 0):
            popsizeCurGeneration = popsizePrevGeneration
        if scaledRecombinationRate > 0 and popsizePrevGeneration > 0 and popsizeCurGeneration > 0:
            self.populate_generation(scaledRecombinationRate, popsizePrevGeneration, popsizeCurGeneration)

    # function to populate haplotypes of this generation 
    def populate_generation(self, scaledRecombinationRate, popsizePrevGeneration, popsizeCurGeneration):
        """Populate the haplotypes of this generation.
        """
        self.haplotypes = [Haplotype(scaledRecombinationRate, popsizePrevGeneration) for x in range(popsizeCurGeneration)]

    # function to print generations information:
    def print_generation(self):
        """Print the information on this generation.
        """
        print("Current population size: %d"%(len(self.haplotypes)))
        for x in range(len(self.haplotypes)):
            self.haplotypes[x].print_haplotype()

# %%
genX = Generation(scaledRecombinationRate=1, popsizePrevGeneration=100)
genX.print_generation()
# Out:
# Current population size: 100
#                  Parents: 92, 76
#              Proportions: 0.134, 0.866
#                  Parents: 77, 65, 75
#              Proportions: 0.058, 0.355, 0.586
#                  Parents: 25, 45, 95
#              Proportions: 0.493, 0.274, 0.233
#                  Parents: 32
#              Proportions: 1.0
#                  Parents: 70, 28, 79
#              Proportions: 0.791, 0.142, 0.067
#                  Parents: 34, 50
#              Proportions: 0.817, 0.183
#                  Parents: 28, 66
#              Proportions: 0.242, 0.758
#                  Parents: 98
#              Proportions: 1.0
#                  Parents: 74, 16
#              Proportions: 0.907, 0.093
#                  Parents: 73, 71, 29
#              Proportions: 0.297, 0.436, 0.266
#                  Parents: 27, 13
#              Proportions: 0.759, 0.241
#                  Parents: 91
#              Proportions: 1.0
#                  Parents: 38
#              Proportions: 1.0
#                  Parents: 34, 88, 0
#              Proportions: 0.666, 0.205, 0.129
#                  Parents: 13, 68
#              Proportions: 0.791, 0.209
#                  Parents: 5, 5
#              Proportions: 0.174, 0.826
#                  Parents: 38
#              Proportions: 1.0
#                  Parents: 15, 96
#              Proportions: 0.223, 0.777
#                  Parents: 15, 28
#              Proportions: 0.021, 0.979
#                  Parents: 86, 96
#              Proportions: 0.718, 0.282
#                  Parents: 39
#              Proportions: 1.0
#                  Parents: 36, 33
#              Proportions: 0.417, 0.583
#                  Parents: 64, 81
#              Proportions: 0.845, 0.155
#                  Parents: 80, 62, 48
#              Proportions: 0.048, 0.35, 0.602
#                  Parents: 29, 93, 15
#              Proportions: 0.252, 0.447, 0.301
#                  Parents: 72, 38
#              Proportions: 0.699, 0.301
#                  Parents: 64
#              Proportions: 1.0
#                  Parents: 18, 12
#              Proportions: 0.73, 0.27
#                  Parents: 34
#              Proportions: 1.0
#                  Parents: 35
#              Proportions: 1.0
#                  Parents: 51
#              Proportions: 1.0
#                  Parents: 94
#              Proportions: 1.0
#                  Parents: 48, 1
#              Proportions: 0.387, 0.613
#                  Parents: 63, 28
#              Proportions: 0.195, 0.805
#                  Parents: 58
#              Proportions: 1.0
#                  Parents: 94, 20
#              Proportions: 0.458, 0.542
#                  Parents: 63
#              Proportions: 1.0
#                  Parents: 86
#              Proportions: 1.0
#                  Parents: 93, 98, 62
#              Proportions: 0.264, 0.077, 0.659
#                  Parents: 45
#              Proportions: 1.0
#                  Parents: 39
#              Proportions: 1.0
#                  Parents: 3, 72, 16
#              Proportions: 0.123, 0.722, 0.155
#                  Parents: 86
#              Proportions: 1.0
#                  Parents: 24
#              Proportions: 1.0
#                  Parents: 45, 79
#              Proportions: 0.403, 0.597
#                  Parents: 95
#              Proportions: 1.0
#                  Parents: 64
#              Proportions: 1.0
#                  Parents: 75, 52, 58, 16
#              Proportions: 0.305, 0.515, 0.099, 0.082
#                  Parents: 34, 43
#              Proportions: 0.152, 0.848
#                  Parents: 16, 50
#              Proportions: 0.053, 0.947
#                  Parents: 64, 96
#              Proportions: 0.744, 0.256
#                  Parents: 98
#              Proportions: 1.0
#                  Parents: 10
#              Proportions: 1.0
#                  Parents: 20, 29
#              Proportions: 0.581, 0.419
#                  Parents: 62, 70
#              Proportions: 0.218, 0.782
#                  Parents: 24
#              Proportions: 1.0
#                  Parents: 66
#              Proportions: 1.0
#                  Parents: 62
#              Proportions: 1.0
#                  Parents: 83, 42
#              Proportions: 0.526, 0.474
#                  Parents: 73, 24, 43
#              Proportions: 0.354, 0.17, 0.477
#                  Parents: 15
#              Proportions: 1.0
#                  Parents: 31, 37
#              Proportions: 0.038, 0.962
#                  Parents: 9, 6
#              Proportions: 0.107, 0.893
#                  Parents: 13, 57
#              Proportions: 0.543, 0.457
#                  Parents: 72, 5
#              Proportions: 0.044, 0.956
#                  Parents: 86
#              Proportions: 1.0
#                  Parents: 60, 60
#              Proportions: 0.495, 0.505
#                  Parents: 12
#              Proportions: 1.0
#                  Parents: 49
#              Proportions: 1.0
#                  Parents: 6
#              Proportions: 1.0
#                  Parents: 53, 0
#              Proportions: 0.628, 0.372
#                  Parents: 2
#              Proportions: 1.0
#                  Parents: 1
#              Proportions: 1.0
#                  Parents: 91, 79, 30
#              Proportions: 0.858, 0.014, 0.127
#                  Parents: 23, 64
#              Proportions: 0.319, 0.681
#                  Parents: 32, 20, 78
#              Proportions: 0.389, 0.006, 0.604
#                  Parents: 3, 35
#              Proportions: 0.654, 0.346
#                  Parents: 20, 30, 3
#              Proportions: 0.003, 0.4, 0.596
#                  Parents: 23, 59
#              Proportions: 0.726, 0.274
#                  Parents: 56, 12
#              Proportions: 0.141, 0.859
#                  Parents: 72, 39
#              Proportions: 0.559, 0.441
#                  Parents: 70
#              Proportions: 1.0
#                  Parents: 56, 61
#              Proportions: 0.45, 0.55
#                  Parents: 86, 45, 64
#              Proportions: 0.084, 0.586, 0.329
#                  Parents: 65, 35
#              Proportions: 0.324, 0.676
#                  Parents: 36
#              Proportions: 1.0
#                  Parents: 58, 92, 96, 62, 55
#              Proportions: 0.138, 0.453, 0.089, 0.032, 0.288
#                  Parents: 59, 55, 28, 87, 54
#              Proportions: 0.497, 0.043, 0.072, 0.021, 0.367
#                  Parents: 0, 10, 95
#              Proportions: 0.797, 0.042, 0.161
#                  Parents: 44, 76
#              Proportions: 0.607, 0.393
#                  Parents: 80
#              Proportions: 1.0
#                  Parents: 70
#              Proportions: 1.0
#                  Parents: 55, 8
#              Proportions: 0.652, 0.348
#                  Parents: 99, 24
#              Proportions: 0.505, 0.495
#                  Parents: 44, 70
#              Proportions: 0.372, 0.628
#                  Parents: 3, 9, 42, 58
#              Proportions: 0.284, 0.254, 0.166, 0.296
#                  Parents: 22
#              Proportions: 1.0
#                  Parents: 82
#              Proportions: 1.0
#                  Parents: 86
#              Proportions: 1.0
#                  Parents: 72, 39
#              Proportions: 0.845, 0.155
